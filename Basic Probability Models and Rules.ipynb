# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def prs_cal() : 

    
    pmb = float(input())
    pab = float(input())
    p1 = float(input())
    p_not_meeting_in_bus = pmb + pab - (2*pmb*pab)
    # prs = p1 * p_not_meeting_in_bus
    prs = p1 * pab * (1 - pmb) + p1 * pmb * (1 - pab)

    print('%.6f' % prs)

prs_cal()
# Out:
# 0.2
# 0.2
# 0.5
# 0.160000
